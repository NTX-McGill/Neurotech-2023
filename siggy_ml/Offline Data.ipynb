# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from erp_classifier import stupid_clf
from parse_offline_data import parse

# %%
X = np.load('X_test_data.npy')
y = np.load('y_test_data.npy')

# %%
clf = stupid_clf()

# %%
X_hit = [X[i] for i in range(len(X)) if y[i] == 1]
X_miss = [X[i] for i in range(len(X)) if y[i] == 0]

# %%
plt.plot(X[0][0])

# %%
len(X_miss)
# Out:
# 127

# %%
plt.plot(clf.preprocess(X_hit[4][5]))

# %%
plt.plot(np.mean(np.mean(clf.preprocess(X_hit), axis = 0), axis = 0))
plt.plot(np.mean(np.mean(clf.preprocess(X_miss), axis = 0), axis = 0))
